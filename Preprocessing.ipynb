# %%
import numpy as np
import sklearn as sk
import librosa
import glob
import os
import pandas as pd

# %%
def preprocess():
    music_data = []
    filelist = []
    featurelist = []
    inst_code = []
    #reading all files recursively
    files = glob.glob('Datasets\TestingData-Part1\Part1\*.wav')
    for filename in files:
        music, sr = librosa.load(filename)
        mfccs = librosa.feature.mfcc(y=music, sr=sr)
        mean_mfccs = np.mean(mfccs, axis = 1)
        feature = mean_mfccs.reshape(20)
        instrument_file = os.path.splitext(filename)[0]+'.txt'
        f = open(instrument_file, 'r')
        instrument = []
        for word in f:
            if 'cel' in word:
                instrument_code = 1
            elif 'cla' in word:
                instrument_code = 2
            elif 'flu' in word:
                instrument_code = 3
            elif 'gac' in word:
                instrument_code = 4
            elif 'gel' in word:
                instrument_code = 5
            elif 'org' in word:
                instrument_code = 6
            elif 'pia' in word:
                instrument_code = 7
            elif 'sax' in word:
                instrument_code = 8
            elif 'tru' in word:
                instrument_code = 9
            elif 'vio' in word:
                instrument_code = 10
            elif 'voi' in word:
                instrument_code = 11
            else:
                instrument_code = 0
            instrument.append(instrument_code)
        filelist.append(filename)
        featurelist.append(feature)
        inst_code.append(instrument)
    df=pd.DataFrame()    
    df['filename']= filelist
    df['feature']= featurelist
    df['instrumentcode']= inst_code
    print df.head(5)
    #file_data = [filename, feature, instrument]
    #music_data.append(file_data)
    #print file_data
    #return music_data
    return df

# %%
def main():
    music_data = preprocess()
    print music_data

# %%
if __name__ == '__main__':
     main()
# Out:
#                                             filename  \
# 0  Datasets\TestingData-Part1\Part1\(02) dont kil...
# 1  Datasets\TestingData-Part1\Part1\(02) dont kil...
# 2  Datasets\TestingData-Part1\Part1\(02) dont kil...
# 3  Datasets\TestingData-Part1\Part1\(02) dont kil...
# 4  Datasets\TestingData-Part1\Part1\(02) dont kil...
#
#                                              feature instrumentcode
# 0  [-85.1709075864, 124.897321171, -41.554643044,...            [5]
# 1  [-35.265214713, 115.867942501, -24.620781264, ...            [5]
# 2  [5.95847028334, 100.027032867, -34.5711421294,...        [5, 11]
# 3  [8.15877521506, 97.0728163323, -31.744432342, ...        [5, 11]
# 4  [6.40971438517, 90.5233774401, -24.6333478839,...        [5, 11]
#                                              filename  \
# 0   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 1   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 2   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 3   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 4   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 5   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 6   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 7   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 8   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 9   Datasets\TestingData-Part1\Part1\(02) dont kil...
# 10  Datasets\TestingData-Part1\Part1\(02) dont kil...
# 11  Datasets\TestingData-Part1\Part1\(02) dont kil...
# 12  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 13  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 14  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 15  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 16  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 17  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 18  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 19  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 20  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 21  Datasets\TestingData-Part1\Part1\00 - gold fro...
# 22  Datasets\TestingData-Part1\Part1\00 - yazoo - ...
# 23  Datasets\TestingData-Part1\Part1\00 - yazoo - ...
# 24  Datasets\TestingData-Part1\Part1\00 - yazoo - ...
# 25  Datasets\TestingData-Part1\Part1\00 - yazoo - ...
# 26  Datasets\TestingData-Part1\Part1\00 - yazoo - ...
# 27    Datasets\TestingData-Part1\Part1\01 - 999-1.wav
# 28   Datasets\TestingData-Part1\Part1\01 - 999-10.wav
# 29   Datasets\TestingData-Part1\Part1\01 - 999-11.wav
# 30   Datasets\TestingData-Part1\Part1\01 - 999-12.wav
# 31   Datasets\TestingData-Part1\Part1\01 - 999-13.wav
# 32   Datasets\TestingData-Part1\Part1\01 - 999-15.wav
# 33   Datasets\TestingData-Part1\Part1\01 - 999-17.wav
# 34   Datasets\TestingData-Part1\Part1\01 - 999-18.wav
# 35    Datasets\TestingData-Part1\Part1\01 - 999-2.wav
# 36   Datasets\TestingData-Part1\Part1\01 - 999-20.wav
# 37    Datasets\TestingData-Part1\Part1\01 - 999-4.wav
# 38    Datasets\TestingData-Part1\Part1\01 - 999-5.wav
# 39    Datasets\TestingData-Part1\Part1\01 - 999-6.wav
# 40    Datasets\TestingData-Part1\Part1\01 - 999-8.wav
# 41  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 42  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 43  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 44  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 45  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 46  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 47  Datasets\TestingData-Part1\Part1\01 - Airdrop-...
# 48  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 49  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 50  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 51  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 52  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 53  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 54  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
# 55  Datasets\TestingData-Part1\Part1\[1] - 03 - Al...
#
#                                               feature instrumentcode
# 0   [-85.1709075864, 124.897321171, -41.554643044,...            [5]
# 1   [-35.265214713, 115.867942501, -24.620781264, ...            [5]
# 2   [5.95847028334, 100.027032867, -34.5711421294,...        [5, 11]
# 3   [8.15877521506, 97.0728163323, -31.744432342, ...        [5, 11]
# 4   [6.40971438517, 90.5233774401, -24.6333478839,...        [5, 11]
# 5   [12.3481249519, 104.67181748, -39.9715917594, ...         [5, 7]
# 6   [-62.8387013923, 121.536287345, -31.4630374217...        [5, 11]
# 7   [-27.1267172748, 106.808997086, -24.7790149163...        [5, 11]
# 8   [-35.9586077328, 117.714180357, -31.4772914162...            [5]
# 9   [-21.0065396005, 103.79834835, -24.2712274242,...        [5, 11]
# 10  [-35.365670226, 115.403750774, -24.6777576557,...            [5]
# 11  [-24.9046392656, 95.4321839863, -21.8929531834...         [5, 7]
# 12  [-201.944465072, 85.761476479, -17.7529970625,...           [11]
# 13  [34.9791765076, 87.9168030518, -13.0139949295,...            [5]
# 14  [-86.0117065205, 134.391792, -49.2641675221, -...        [7, 11]
# 15  [-111.723453275, 123.564623683, 18.0417278586,...        [4, 11]
# 16  [9.49189694531, 94.109192432, -8.43024207877, ...        [5, 11]
# 17  [19.8274943998, 89.2073492507, -8.60744006981,...        [5, 11]
# 18  [-5.49254644536, 82.0951987685, 3.8527853803, ...        [5, 11]
# 19  [-5.47017241738, 109.556853232, -8.71608989946...        [5, 11]
# 20  [30.035186062, 84.2473225339, -7.1063101375, 3...        [5, 11]
# 21  [10.3233668985, 81.6629048374, 1.43518951497, ...        [5, 11]
# 22  [-155.111310988, 88.4841918106, 11.7126143669,...           [11]
# 23  [-157.950302887, 96.6445741284, 7.26109050595,...           [11]
# 24  [-137.796394571, 88.4797417056, 5.11194218469,...           [11]
# 25  [-155.712929632, 87.2507775066, 14.6546008332,...           [11]
# 26  [-138.257237591, 88.146528495, 7.67156770327, ...           [11]
# 27  [-75.5321082461, 103.742239877, -20.1509098478...            [5]
# 28  [-18.6278295797, 86.7255985577, -10.1077577145...        [5, 11]
# 29  [-8.71011168345, 86.4926791141, -15.4306455923...     [5, 6, 11]
# 30  [-18.5069731534, 84.3412562593, -15.4859449758...        [5, 11]
# 31  [-21.1963784032, 81.9207073537, -8.1681111509,...        [5, 11]
# 32  [-13.2569921541, 95.2045323729, -20.3714774321...     [5, 6, 11]
# 33  [-14.4740997441, 83.527178277, -9.02643774769,...        [5, 11]
# 34  [-15.4125704969, 89.7677336849, -20.499332584,...        [5, 11]
# 35  [-60.67390934, 101.288516377, -6.32591817746, ...        [5, 11]
# 36  [-5.60661911821, 94.9298643356, -30.3577540808...     [5, 6, 11]
# 37  [-58.0698926293, 102.989169549, -11.7513215573...        [5, 11]
# 38  [-35.1893202251, 100.128364092, -18.2011379468...     [5, 6, 11]
# 39  [-39.124798996, 89.9244586613, -6.65264372537,...        [5, 11]
# 40  [-30.7138569065, 91.4125935527, -9.14054519254...     [5, 6, 11]
# 41  [-241.135937902, 128.57725112, -67.9091129344,...            [5]
# 42  [-160.406265245, 148.294731266, -46.7214217582...            [5]
# 43  [-192.625577474, 119.152900931, -46.2981636396...        [5, 11]
# 44  [3.55478860947, 95.1974526353, -31.3632407759,...         [1, 5]
# 45  [56.008471573, 74.3224270709, -19.156533963, 2...        [5, 11]
# 46  [59.7191437694, 87.5408825069, -30.3512463016,...            [5]
# 47  [62.3375193745, 85.1601662815, -30.8750753962,...            [5]
# 48  [-346.526710526, 175.370497951, -1.65805487438...            [4]
# 49  [-352.156116772, 183.532485418, 1.3021598451, ...            [4]
# 50  [-345.248440498, 166.137895709, -1.21024582138...            [4]
# 51  [-334.075674427, 174.220472958, 0.10313596464,...            [4]
# 52  [-347.417182709, 182.345223664, 0.045637790763...            [4]
# 53  [-301.261777032, 156.741653998, 6.02939969775,...            [4]
# 54  [-289.675048509, 170.22292955, 3.88138928178, ...            [4]
# 55  [-282.656261406, 170.060789431, -6.62641371965...            [4]
